# %% [markdown]
# # Making Web Requests with Python
# When you use your browser to visit a website, your computer is
#
# 1. making a web request,
# 2. pulling back the page data (i.e. the page HTML)
# 3. rendering the page in your browser.
#
# We can use Python to perform the first 2 of these steps, thus getting the web page data into a Python object.  Once we've done this we can manipulate the data in Python.

# %% [markdown]
# ## A Simple Web Request
# First let's use Python to make a simple request to a web page.

# %%
# Import the library
import requests

# Issue the request
r = requests.get("https://a-z-animals.com/animals/")

# %%
# Get the status code - 200 means we got the page back.  404 means we didn't
r.status_code
# Out:
# 200

# %%
# What type of data is this?
r.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
# What character encoding is this?  
r.encoding
# Out:
# 'UTF-8'

# %%
# What's the actual content?
r.text
# Out:
# '<!DOCTYPE html><html lang="en-US" uucss><head><meta charset="UTF-8" /><meta name="viewport" content="width=device-width, initial-scale=1" /><meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' /> <script data-cfasync="false">window.dataLayer = window.dataLayer || [];\n            function gtag(){dataLayer.push(arguments);}\n\n            window.pageVars = {\n                \'publish_date\': \'2020-12-06T19:35:47+00:00\',\n                \'modified_date\': \'2021-04-17T01:07:56+00:00\'\n            }\n\n            //custom dimensions\n            gtag(\'set\',\n                {\n                    \'custom_map\':\n                        {\n                            \'dimension1\': \'ad_blocking\',  //session level dim\n                            \'dimension2\': \'subscriber\',   //session level dim\n                            \'dimension3\': \'ad_served\',    //hit level dim\n                            \'dimension4\': \'subscribed\',   //user level dim\n                            \'dimension5\': \'published_date\',    //hit level dim\n                            \'dimension6\': \'modified_date\',    //hit level dim\n                            \'dimension7\': \'content_tags\',    //hit level dim\n                        }\n                });\n\n            var gtagVars = { \'anonymize_ip\': true };\n                gtagVars[\'published_date\'] = \'20201206\';\n                gtagVars[\'modified_date\'] = \'20210417\';\n                gtagVars[\'content_tags\'] = \'\';\n            gtag(\'js\', new Date());\n            //Production:\n            gtag(\'config\', \'UA-487288-3\', gtagVars);\n            //Dev:\n            //gtag(\'config\', \'UA-149868784-2\', gtagVars);</script> <script async src="https://www.googletagmanager.com/gtag/js?id=UA-487288-3"></script> <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-KCTKMC6\');</script> <style>.adthrive-ad {\n\t\tmargin-top: 10px;\n\t\tmargin-bottom: 10px;\n\t\ttext-align: center;\n\t\toverflow-x: visible;\n\t\tclear: both;\n\t\tline-height: 0;\n\t}\n\t.adthrive-ad {\nclear: none;\n}\n\n.body_animal .adthrive-content, \n.az-animals-index .adthrive-content {\nclear: both;\n}\n\n.adthrive-header,\n.adthrive-sidebar-1 {\n  margin: 0;\n}\n\n@media (min-width: 768px) {\nbody.page-template-animals-by-letter .adthrive-content {\n    flex: 0 0 33.333333%;\n    max-width: 33.333333%;\n}\n}\n\n/* Fix for left aligned ads, 10/11/19 */\n.adthrive-ad > div[id^=\'google_ads_iframe\'] {display: block !important;}\n\n/* Fix for CLS video container not respecting site width */\n.adthrive-device-desktop div[id^="cls-video-container"],\n.adthrive-device-tablet div[id^="cls-video-container"] {\n    min-width: unset !important;\n    max-width: 600px;\n    max-height: 400px;\n    min-height: unset !important;\n    margin: 10px auto;\n}</style> <script>window.adthriveCLS = {\n\t\tenabledLocations: [\'Content\', \'Recipe\'],\n\t\tinjectedSlots: [],\n\t\tinjectedFromPlugin: true, // accessed by site specific file injection\n\t\t\t};\n\twindow.adthriveCLS.siteAds = {"targeting":[{"value":"5daf495ed42c8605cfc74b0b","key":"siteId"},{"value":"AZ Animals","key":"siteName"},{"value":"AdThrive Edge","key":"service"},{"value":"on","key":"bidding"},{"value":null,"key":"dynamicVersion"},{"value":["Pets"],"key":"verticals"}],"siteId":"5daf495ed42c8605cfc74b0b","siteName":"AZ Animals","adOptions":{"theTradeDesk":true,"unruly":true,"verizon":true,"mediaGrid":true,"undertone":false,"comscoreFooter":true,"footerCloseButton":false,"teads":true,"districtM":true,"comscoreTAL":true,"pmp":false,"brightroll":true,"kargo":true,"thirtyThreeAcross":tru ...

# %% [markdown]
# What have we actually done here?  We've pulled the web page content into Python.  Just to prove it, we can write the content to a file and display the page:

# %%
import os

# Write content to a file
f = open("animals.html", "w")
f.write(r.text)
f.close()

# Display the file
os.startfile("animals.html")   # doesn't work on Mac

# %% [markdown]
# Note that the images and styles are not showing because we haven't downloaded those.

# %% [markdown]
# # Your turn>>
# Download a page from your favourite website.

# %%
# Enter your code here
import requests 
r = requests.get("https://www.google.com")
r.status_code
r.headers['content-type']
r.encoding
r.text

# %% [markdown]
# # Your turn>>
# Use the Programmable Web site to find APIs that might be of interest to you.
#
# https://www.programmableweb.com
